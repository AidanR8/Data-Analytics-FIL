# %%
#practice only on fresh file#

# %%
import requests

# %%
data=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo")
data
# Out:
# <Response [200]>

# %%
data.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2022-06-17 19:35:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2022-06-17 19:35:00': {'1. open': '135.4800',
#    '2. high': '135.4800',
#    '3. low': '135.4800',
#    '4. close': '135.4800',
#    '5. volume': '300'},
#   '2022-06-17 18:45:00': {'1. open': '135.5000',
#    '2. high': '135.5000',
#    '3. low': '135.5000',
#    '4. close': '135.5000',
#    '5. volume': '650'},
#   '2022-06-17 17:55:00': {'1. open': '135.0200',
#    '2. high': '135.0200',
#    '3. low': '135.0200',
#    '4. close': '135.0200',
#    '5. volume': '3301'},
#   '2022-06-17 17:35:00': {'1. open': '135.0400',
#    '2. high': '135.0400',
#    '3. low': '135.0400',
#    '4. close': '135.0400',
#    '5. volume': '301'},
#   '2022-06-17 17:15:00': {'1. open': '135.0400',
# ...

# %%
type(data.json())
# Out:
# dict

# %%
data["Time Series 5min"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 data["Time Series 5min"]
#
# TypeError: 'Response' object is not subscriptable

# %%
data=data.json()

# %%
data["Time Series (5min)"]
# Out:
# {'2022-06-17 19:35:00': {'1. open': '135.4800',
#   '2. high': '135.4800',
#   '3. low': '135.4800',
#   '4. close': '135.4800',
#   '5. volume': '300'},
#  '2022-06-17 18:45:00': {'1. open': '135.5000',
#   '2. high': '135.5000',
#   '3. low': '135.5000',
#   '4. close': '135.5000',
#   '5. volume': '650'},
#  '2022-06-17 17:55:00': {'1. open': '135.0200',
#   '2. high': '135.0200',
#   '3. low': '135.0200',
#   '4. close': '135.0200',
#   '5. volume': '3301'},
#  '2022-06-17 17:35:00': {'1. open': '135.0400',
#   '2. high': '135.0400',
#   '3. low': '135.0400',
#   '4. close': '135.0400',
#   '5. volume': '301'},
#  '2022-06-17 17:15:00': {'1. open': '135.0400',
#   '2. high': '135.0400',
#   '3. low': '135.0400',
#   '4. close': '135.0400',
#   '5. volume': '400'},
#  '2022-06-17 17:10:00': {'1. open': '135.0700',
#   '2. high': '135.0700',
#   '3. low': '135.0500',
#   '4. close': '135.0500',
#   '5. volume': '1305'},
#  '2022-06-17 17:05:00': {'1. open': '135.2699',
# ...

# %%
#Find out how to get data timestamp as rows and 1 / 2 /3 etc as columns

# %%
#changing data to be different than Shubham's

# %%
data=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2022-06-17',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2022-06-17': {'1. open': '135.9900',
#    '2. high': '136.9800',
#    '3. low': '132.8500',
#    '4. close': '135.0200',
#    '5. volume': '12968509'},
#   '2022-06-16': {'1. open': '135.3000',
#    '2. high': '136.2400',
#    '3. low': '134.3900',
#    '4. close': '135.6700',
#    '5. volume': '5386396'},
#   '2022-06-15': {'1. open': '136.0100',
#    '2. high': '138.4500',
#    '3. low': '135.5800',
#    '4. close': '137.0600',
#    '5. volume': '4606887'},
#   '2022-06-14': {'1. open': '135.0000',
#    '2. high': '136.9501',
#    '3. low': '134.8600',
#    '4. close': '135.7200',
#    '5. volume': '4607785'},
#   '2022-06-13': {'1. open': '133.9700',
#    '2. high': '137.5700',
#    '3. low': '133.7600',
#    '4. close': '135.1100',
# ...

# %%
data=data.json()

# %%
data["Time Series (Daily)"]
# Out:
# {'2022-06-17': {'1. open': '135.9900',
#   '2. high': '136.9800',
#   '3. low': '132.8500',
#   '4. close': '135.0200',
#   '5. volume': '12968509'},
#  '2022-06-16': {'1. open': '135.3000',
#   '2. high': '136.2400',
#   '3. low': '134.3900',
#   '4. close': '135.6700',
#   '5. volume': '5386396'},
#  '2022-06-15': {'1. open': '136.0100',
#   '2. high': '138.4500',
#   '3. low': '135.5800',
#   '4. close': '137.0600',
#   '5. volume': '4606887'},
#  '2022-06-14': {'1. open': '135.0000',
#   '2. high': '136.9501',
#   '3. low': '134.8600',
#   '4. close': '135.7200',
#   '5. volume': '4607785'},
#  '2022-06-13': {'1. open': '133.9700',
#   '2. high': '137.5700',
#   '3. low': '133.7600',
#   '4. close': '135.1100',
#   '5. volume': '6486044'},
#  '2022-06-10': {'1. open': '137.8000',
#   '2. high': '137.8000',
#   '3. low': '135.2500',
#   '4. close': '136.1900',
#   '5. volume': '4661716'},
#  '2022-06-09': {'1. open': '140.1500',
#   '2. high': '141.0400',
# ...

# %%
df=pd.read_json("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df=pd.read_json("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df=pd.read_json("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
df.head()
# Out:
#                                                            Meta Data  \
# 1. Information     Daily Prices (open, high, low, close) and Volumes
# 2. Symbol                                                        IBM
# 3. Last Refreshed                                         2022-06-17
# 4. Output Size                                               Compact
# 5. Time Zone                                              US/Eastern
#
#                   Time Series (Daily)
# 1. Information                    NaN
# 2. Symbol                         NaN
# 3. Last Refreshed                 NaN
# 4. Output Size                    NaN
# 5. Time Zone                      NaN

# %%
r = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
df = pd.read_json(x.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 r = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
# ----> 2 df = pd.read_json(x.text)
#
# NameError: name 'x' is not defined

# %%
r = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
x = r.json()
df = pd.read_json(json.dumps(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 3>()
#       1 r = requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
#       2 x = r.json()
# ----> 3 df = pd.read_json(json.dumps(x))
#
# NameError: name 'json' is not defined

# %%
data.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 data.json()
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
import requests

# %%
data=requests.get("https://www.alphavantage.co/query?function=CRYPTO_INTRADAY&symbol=ETH&market=USD&interval=5min&apikey=demo")
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Crypto Intraday (5min) Time Series',
#   '2. Digital Currency Code': 'ETH',
#   '3. Digital Currency Name': 'Ethereum',
#   '4. Market Code': 'USD',
#   '5. Market Name': 'United States Dollar',
#   '6. Last Refreshed': '2022-06-18 19:25:00',
#   '7. Interval': '5min',
#   '8. Output Size': 'Compact',
#   '9. Time Zone': 'UTC'},
#  'Time Series Crypto (5min)': {'2022-06-18 19:25:00': {'1. open': '939.03000',
#    '2. high': '941.97000',
#    '3. low': '933.30000',
#    '4. close': '934.15000',
#    '5. volume': 11018},
#   '2022-06-18 19:20:00': {'1. open': '937.48000',
#    '2. high': '943.50000',
#    '3. low': '935.34000',
#    '4. close': '939.02000',
#    '5. volume': 10156},
#   '2022-06-18 19:15:00': {'1. open': '934.53000',
#    '2. high': '944.42000',
#    '3. low': '933.03000',
#    '4. close': '937.47000',
#    '5. volume': 9034},
#   '2022-06-18 19:10:00': {'1. open': '936.14000',
#    '2. high': '938.52000',
#    '3. low': '932.43000',
# ...

# %%
import pandas as pd

# %%
data["open"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 data["open"]
#
# TypeError: 'Response' object is not subscriptable
