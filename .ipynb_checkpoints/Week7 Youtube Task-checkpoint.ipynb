# %%
import pandas as pd

# %%
CAvideos=pd.read_csv("CAvideos.csv")
DEvideos=pd.read_csv("DEvideos.csv")

# %%
# concat example

# %%
concat_data=(CAvideos,DEvideos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 concat_data(CAvideos,DEvideos)
#
# NameError: name 'concat_data' is not defined

# %%
concat_data=(CAvideos,DEvideos)

# %%
concat_data
# Out:
# (          video_id trending_date  \
#  0      n1WpP7iowLc      17.14.11
#  1      0dBIkQ4Mz1M      17.14.11
#  2      5qpjK5DgCt4      17.14.11
#  3      d380meD0W0M      17.14.11
#  4      2Vv-BfVoq4g      17.14.11
#  ...            ...           ...
#  40876  sGolxsMSGfQ      18.14.06
#  40877  8HNuRNi8t70      18.14.06
#  40878  GWlKEM3m2EE      18.14.06
#  40879  lbMKLzQ4cNQ      18.14.06
#  40880  POTgw38-m58      18.14.06
#
#                                                     title     channel_title  \
#  0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
#  1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
#  2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
#  3                               I Dare You: GOING BALD!?          nigahiga
#  4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
#  ...                                                  ...               ...
# ...

# %%
display(concat_data)
# Out:
# (          video_id trending_date  \
#  0      n1WpP7iowLc      17.14.11
#  1      0dBIkQ4Mz1M      17.14.11
#  2      5qpjK5DgCt4      17.14.11
#  3      d380meD0W0M      17.14.11
#  4      2Vv-BfVoq4g      17.14.11
#  ...            ...           ...
#  40876  sGolxsMSGfQ      18.14.06
#  40877  8HNuRNi8t70      18.14.06
#  40878  GWlKEM3m2EE      18.14.06
#  40879  lbMKLzQ4cNQ      18.14.06
#  40880  POTgw38-m58      18.14.06
#
#                                                     title     channel_title  \
#  0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
#  1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
#  2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
#  3                               I Dare You: GOING BALD!?          nigahiga
#  4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
#  ...                                                  ...               ...
# ...

# %%
# this reuslt is difficult to interpret so we will try JOIN

# %%
left = CAvideos.set_index(['title','trending_date'])
right = DEvideos.set_index(['title','trending_date'])

# %%
join_data = left.join(right, lsuffix='_CA', rsuffix='_DE')

# %%
print(join_data)
# Out:
#                                                                   video_id_CA  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       bYvQmusLaxw
#                                                    17.21.12       bYvQmusLaxw
# ...                                                                       ...
# 😲She Is So Nervous But BLOWS The ROOF After Tak... 18.02.05       WttN1Z0XF4k
#                                                    18.29.04       WttN1Z0XF4k
#                                                    18.30.04       WttN1Z0XF4k
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# ...

# %%
display(join_data)
# Out:
#                                                                   video_id_CA  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       bYvQmusLaxw
#                                                    17.21.12       bYvQmusLaxw
# ...                                                                       ...
# 😲She Is So Nervous But BLOWS The ROOF After Tak... 18.02.05       WttN1Z0XF4k
#                                                    18.29.04       WttN1Z0XF4k
#                                                    18.30.04       WttN1Z0XF4k
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# ...

# %%
merged_data= pd.merge(left,right,on='video_id')
display(merged_data)
# Out:
#           video_id    channel_title_x  category_id_x  \
# 0      n1WpP7iowLc         EminemVEVO             10
# 1      n1WpP7iowLc         EminemVEVO             10
# 2      n1WpP7iowLc         EminemVEVO             10
# 3      n1WpP7iowLc         EminemVEVO             10
# 4      0dBIkQ4Mz1M          iDubbbzTV             23
# ...            ...                ...            ...
# 21507  G4g2Kg6wXBc  Think Music India              1
# 21508  RtI8iieSHqU                 M2             24
# 21509  WjORQit3eNk                WWE             17
# 21510  pP9fQZsstIg         Télé Maroc             22
# 21511  7E1np354AEc          Россия 24             24
#
#                  publish_time_x  \
# 0      2017-11-10T17:00:03.000Z
# 1      2017-11-10T17:00:03.000Z
# 2      2017-11-10T17:00:03.000Z
# 3      2017-11-10T17:00:03.000Z
# 4      2017-11-13T17:00:00.000Z
# ...                         ...
# 21507  2018-06-13T05:57:12.000Z
# 21508  2018-06-13T12:00:02.000Z
# ...

# %%
merged_data= pd.merge(left, 
right [['video_id','views','likes','dislikes']], 
on='video_id’,
how='left/right/outer')
# Out:
#   Input In [14]
#     on='video_id’,
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
concat_data=(CAvideos,DEvideos)
concat_data
# Out:
# (          video_id trending_date  \
#  0      n1WpP7iowLc      17.14.11
#  1      0dBIkQ4Mz1M      17.14.11
#  2      5qpjK5DgCt4      17.14.11
#  3      d380meD0W0M      17.14.11
#  4      2Vv-BfVoq4g      17.14.11
#  ...            ...           ...
#  40876  sGolxsMSGfQ      18.14.06
#  40877  8HNuRNi8t70      18.14.06
#  40878  GWlKEM3m2EE      18.14.06
#  40879  lbMKLzQ4cNQ      18.14.06
#  40880  POTgw38-m58      18.14.06
#
#                                                     title     channel_title  \
#  0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
#  1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
#  2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
#  3                               I Dare You: GOING BALD!?          nigahiga
#  4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
#  ...                                                  ...               ...
# ...

# %%
concat_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 concat_data.head()
#
# AttributeError: 'tuple' object has no attribute 'head'

# %%
concat_data= pd.concat([CAvideos,DEvideos])

# %%
concat_data
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40835  fn5WNxy-Wcw      18.14.06
# 40836  zAFv43lxqHE      18.14.06
# 40837  zSXG5I6Y2fA      18.14.06
# 40838  5d115sePmaU      18.14.06
# 40839  go-F6xvezAM      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40835  KINGDOM HEARTS III – E3 2018 Pirates of the Ca...
# 40836                                     YMS: The Visit
# ...

# %%
display(concat_data)
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40835  fn5WNxy-Wcw      18.14.06
# 40836  zAFv43lxqHE      18.14.06
# 40837  zSXG5I6Y2fA      18.14.06
# 40838  5d115sePmaU      18.14.06
# 40839  go-F6xvezAM      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                               I Dare You: GOING BALD!?
# 4            Ed Sheeran - Perfect (Official Music Video)
# ...                                                  ...
# 40835  KINGDOM HEARTS III – E3 2018 Pirates of the Ca...
# 40836                                     YMS: The Visit
# ...

# %%
#concat is the best solution in this insatance as tables/data are exactly the same in terms of number of columns and column headers

# %%
concat_data.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
ed_sheeran_views = concat_data[concat_data['Channel_title'] == 'Ed Sheeran'].groupby('views').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Channel_title'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
ed_sheeran_views = concat_data[concat_data['channel_title'] == 'Ed Sheeran'].groupby('likes').sum()

# %%
ed_sheeran_views
# Out:
#           category_id    likes  dislikes  comment_count  comments_disabled  \
# views
# 359900             10    46148       352           2911                  0
# 906053             20   186540      1694           9434                  0
# 2157281            20   283297      4050          13026                  0
# 2932251            20   322933      5046          14544                  0
# 3702038            10   174101      2887           7629                  0
# 4279908            10   181762      3153           8173                  0
# 5907608            20  1128385     17874          70310                  0
# 5988303            20  1065784     11044          45286                  0
# 8130538            20  1287561     19398          70882                  0
# 10999974           20  1437016     19578          58188                  0
# 11618399           20  1598550     32328          93806                  0
# ...

# %%
ed_sheeran_views.plot()
# Out:
# <AxesSubplot:xlabel='views'>

# %%
ed_sheeran_likes = concat_data[concat_data['channel_title'] == 'Ed Sheeran'].groupby('likes').sum()

# %%
ed_sheeran_likes = concat_data[concat_data['channel_title'] == 'Ed Sheeran'].groupby('likes').sum()

# %%
ed_sheeran_likes.plot()
# Out:
# <AxesSubplot:xlabel='likes'>

# %%
# useful video on this https://realpython.com/lessons/visualizing-pandas-dataframe/
