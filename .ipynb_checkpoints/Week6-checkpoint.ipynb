# %%
import requests

# %%
data=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=5min&apikey=8DV7BJU8CRZYJTE9")
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2022-06-17 20:00:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2022-06-17 20:00:00': {'1. open': '131.5300',
#    '2. high': '131.5600',
#    '3. low': '131.5200',
#    '4. close': '131.5600',
#    '5. volume': '1549'},
#   '2022-06-17 19:55:00': {'1. open': '131.5200',
#    '2. high': '131.5700',
#    '3. low': '131.5200',
#    '4. close': '131.5700',
#    '5. volume': '3690'},
#   '2022-06-17 19:50:00': {'1. open': '131.5200',
#    '2. high': '131.5200',
#    '3. low': '131.5000',
#    '4. close': '131.5200',
#    '5. volume': '2068'},
#   '2022-06-17 19:45:00': {'1. open': '131.5300',
#    '2. high': '131.5300',
#    '3. low': '131.5200',
#    '4. close': '131.5200',
#    '5. volume': '941'},
#   '2022-06-17 19:40:00': {'1. open': '131.5200',
# ...

# %%
type.data.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 type.data.json()
#
# AttributeError: type object 'type' has no attribute 'data'

# %%
data=data.json()

# %%
data
# Out:
# {'message': 'success',
#  'timestamp': 1655575751,
#  'iss_position': {'longitude': '-54.1617', 'latitude': '26.9141'}}

# %%
# Out:
#   Input In [14]
#     data[""'Time Series (5min)'"]
#                                  ^
# SyntaxError: EOL while scanning string literal

# %%
data['Time Series (5min)']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 data['Time Series (5min)']
#
# TypeError: 'Response' object is not subscriptable

# %%
data["Time Series (5min)"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 data["Time Series (5min)"]
#
# TypeError: 'Response' object is not subscriptable

# %%
data['Time Series (5min)']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 data['Time Series (5min)']
#
# TypeError: 'Response' object is not subscriptable

# %%
data=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=AAPL&interval=5min&apikey=8DV7BJU8CRZYJTE9")
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2022-06-17 20:00:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2022-06-17 20:00:00': {'1. open': '131.5300',
#    '2. high': '131.5600',
#    '3. low': '131.5200',
#    '4. close': '131.5600',
#    '5. volume': '1549'},
#   '2022-06-17 19:55:00': {'1. open': '131.5200',
#    '2. high': '131.5700',
#    '3. low': '131.5200',
#    '4. close': '131.5700',
#    '5. volume': '3690'},
#   '2022-06-17 19:50:00': {'1. open': '131.5200',
#    '2. high': '131.5200',
#    '3. low': '131.5000',
#    '4. close': '131.5200',
#    '5. volume': '2068'},
#   '2022-06-17 19:45:00': {'1. open': '131.5300',
#    '2. high': '131.5300',
#    '3. low': '131.5200',
#    '4. close': '131.5200',
#    '5. volume': '941'},
#   '2022-06-17 19:40:00': {'1. open': '131.5200',
# ...

# %%
data["Time Series (5min)"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 data["Time Series (5min)"]
#
# TypeError: 'Response' object is not subscriptable

# %%
data["high"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 data["high"]
#
# TypeError: 'Response' object is not subscriptable

# %%
data=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo")

# %%
print(data)
# Out:
# <Response [200]>

# %%
data
# Out:
# <Response [200]>

# %%
data.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
data.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'IBM',
#   '3. Last Refreshed': '2022-06-17 19:35:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2022-06-17 19:35:00': {'1. open': '135.4800',
#    '2. high': '135.4800',
#    '3. low': '135.4800',
#    '4. close': '135.4800',
#    '5. volume': '300'},
#   '2022-06-17 18:45:00': {'1. open': '135.5000',
#    '2. high': '135.5000',
#    '3. low': '135.5000',
#    '4. close': '135.5000',
#    '5. volume': '650'},
#   '2022-06-17 17:55:00': {'1. open': '135.0200',
#    '2. high': '135.0200',
#    '3. low': '135.0200',
#    '4. close': '135.0200',
#    '5. volume': '3301'},
#   '2022-06-17 17:35:00': {'1. open': '135.0400',
#    '2. high': '135.0400',
#    '3. low': '135.0400',
#    '4. close': '135.0400',
#    '5. volume': '301'},
#   '2022-06-17 17:15:00': {'1. open': '135.0400',
# ...

# %%
data["Time Series (5min)"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 data["Time Series (5min)"]
#
# TypeError: 'Response' object is not subscriptable

# %%
data["Meta Data"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 data["Meta Data"]
#
# TypeError: 'Response' object is not subscriptable
